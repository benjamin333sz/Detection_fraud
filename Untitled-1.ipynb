# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\couea\downloads\finance\.venv\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\couea\downloads\finance\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\couea\downloads\finance\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\couea\downloads\finance\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# nous lisons le fichier csv
path=r"Input_projet_LVMH.csv"

data= pd.read_csv(path,sep=";")
# nous affichons les types de données et les valeurs manquantes
data.info()
print(data.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5119 entries, 0 to 5118
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    5119 non-null   str
#  1   clot    5119 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 80.1 KB
# date    0
# clot    0
# dtype: int64

# %%
# Convertir la colonne date en datetime
data['date'] = pd.to_datetime(data['date'], format='%d/%m/%Y')

# Extraire l'année
data['year'] = data['date'].dt.year

# Créer les box plots par année
plt.figure(figsize=(14, 6))
data.boxplot(column='clot', by='year', figsize=(14, 6))
plt.suptitle('Box plots des prix de clôture LVMH par année')
plt.xlabel('Année')
plt.ylabel('Prix de clôture')
plt.show()
